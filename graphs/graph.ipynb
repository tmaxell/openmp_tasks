# %%
# Первое задание
import matplotlib.pyplot as plt

# Данные из логов
sizes = [100, 10000, 100000, 1000000]
time_with_reduction = [0.000301123, 0.000299215, 0.000653028, 0.00148916]
time_without_reduction = [0.000120878, 0.00180197, 0.056627, 0.713945]

# Рассчитываем ускорение
speedup = [time_without_reduction[i] / time_with_reduction[i] for i in range(len(sizes))]

# График времени выполнения с редукцией и без
plt.figure(figsize=(10, 5))

# Время выполнения с редукцией
plt.subplot(1, 2, 1)
plt.plot(sizes, time_with_reduction, label='With Reduction', marker='o', color='b')
plt.plot(sizes, time_without_reduction, label='Without Reduction', marker='o', color='r')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Array Size (log scale)')
plt.ylabel('Execution Time (log scale) [seconds]')
plt.title('Execution Time: With vs Without Reduction')
plt.legend()

# График ускорения
plt.subplot(1, 2, 2)
plt.plot(sizes, speedup, label='Speedup', marker='o', color='g')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Array Size (log scale)')
plt.ylabel('Speedup')
plt.title('Speedup: Without / With Reduction')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Задание 2
import matplotlib.pyplot as plt
import numpy as np

# Данные из логов
sizes = [10000, 100000, 1000000, 10000000, 100000000]  # Размер вектора
times_with_reduction = [0.000513077, 0.00142717, 0.00687194, 0.070051, 1.66639]  # Время с редукцией
times_without_reduction = [0.00032115, 0.00111103, 0.00757194, 0.0706689, 2.29206]  # Время без редукции

# Рассчитываем ускорение
speedup = np.array(times_without_reduction) / np.array(times_with_reduction)

# Построение графика времени выполнения
plt.figure(figsize=(12, 6))

# График времени с редукцией
plt.subplot(1, 2, 1)
plt.plot(sizes, times_with_reduction, label='With Reduction', marker='o', linestyle='-', color='b')
plt.plot(sizes, times_without_reduction, label='Without Reduction', marker='o', linestyle='-', color='r')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Vector Size (log scale)')
plt.ylabel('Time (seconds) (log scale)')
plt.title('Execution Time vs. Vector Size')
plt.legend()

# График ускорения
plt.subplot(1, 2, 2)
plt.plot(sizes, speedup, marker='o', linestyle='-', color='g')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Vector Size (log scale)')
plt.ylabel('Speedup (log scale)')
plt.title('Speedup vs. Vector Size')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Данные (число разбиений N, время выполнения для последовательного и параллельного методов, ускорение)
N_values = [10000, 100000, 1000000, 100000000, 1000000000]
sequential_times = [0.000140905, 0.00272989, 0.0158801, 0.789132, 7.59109]
parallel_times = [0.000625134, 0.000916004, 0.00463104, 0.185301, 3.02436]
speedups = [0.2254, 2.98022, 3.42906, 4.25865, 2.50998]

# Создаем фигуру с двумя подграфиками
fig, ax = plt.subplots(1, 2, figsize=(14, 6))  # 1 строка, 2 столбца

# График времени выполнения
ax[0].plot(N_values, sequential_times, label="Sequential Time", color='blue', marker='o')
ax[0].plot(N_values, parallel_times, label="Parallel Time", color='red', marker='s')

# Настройки для графика времени
ax[0].set_xlabel("Number of Subdivisions (N)")
ax[0].set_ylabel("Execution Time (seconds)")
ax[0].set_xscale('log')
ax[0].set_yscale('log')  # Логарифмическая шкала для лучшего отображения данных на больших значениях N
ax[0].set_title("Execution Time Comparison (Sequential vs Parallel)")
ax[0].legend()

# График ускорения
ax[1].plot(N_values, speedups, label="Speedup", color='green', marker='^')

# Настройки для графика ускорения
ax[1].set_xlabel("Number of Subdivisions (N)")
ax[1].set_ylabel("Speedup (sequential / parallel)")
ax[1].set_xscale('log')
ax[1].set_title("Speedup (Sequential vs Parallel)")
ax[1].legend()

# Отображение графиков
plt.tight_layout()  # Автоматическое выравнивание подграфиков
plt.show()

# %%
# 4 задание
import matplotlib.pyplot as plt

# Данные экспериментов
matrix_sizes = ["100x100", "1000x1000", "10000x10000"]
sequential_times = [0.0000870228, 0.00606894, 0.413307]
parallel_times = [0.00161386, 0.00155687, 0.075141]
speedup = [seq / par for seq, par in zip(sequential_times, parallel_times)]

# Построение графиков
fig, ax1 = plt.subplots()

# График времени выполнения
ax1.set_xlabel("Matrix Size")
ax1.set_ylabel("Execution Time (s)", color="tab:blue")
ax1.plot(matrix_sizes, sequential_times, label="Sequential Time", marker="o", color="tab:blue", linestyle="-")
ax1.plot(matrix_sizes, parallel_times, label="Parallel Time", marker="o", color="tab:cyan", linestyle="--")
ax1.tick_params(axis="y", labelcolor="tab:blue")
ax1.legend(loc="upper left")

# График ускорения
ax2 = ax1.twinx()
ax2.set_ylabel("Speedup", color="tab:red")
ax2.plot(matrix_sizes, speedup, label="Speedup", marker="s", color="tab:red", linestyle="-.")
ax2.tick_params(axis="y", labelcolor="tab:red")
ax2.legend(loc="upper right")

# Финальная настройка и отображение графика
plt.title("Performance Analysis: Sequential vs Parallel (OpenMP)")
fig.tight_layout()
plt.show()

# %%
# задание 5
import matplotlib.pyplot as plt

# Данные экспериментов
matrix_sizes = [100, 1000, 10000, 100000]
bandwidths = [100, 1000, 10000, 100000]
time_static = [0.000892162, 0.00261188, 0.0977612, 61.4193]
time_dynamic = [0.000431776, 0.00160217, 0.103864, 90.442]
time_guided = [0.000306129, 0.0016439, 0.100037, 162.39]

# Построение графиков
plt.figure(figsize=(10, 6))

# Линии для каждого метода
plt.plot(matrix_sizes, time_static, label='Static Scheduling', marker='o')
plt.plot(matrix_sizes, time_dynamic, label='Dynamic Scheduling', marker='s')
plt.plot(matrix_sizes, time_guided, label='Guided Scheduling', marker='^')

# Настройки графика
plt.xscale('log')  # Логарифмическая шкала для оси X
plt.yscale('log')  # Логарифмическая шкала для оси Y
plt.xlabel('Matrix Size (N x N)', fontsize=12)
plt.ylabel('Execution Time (seconds)', fontsize=12)
plt.title('Execution Time by Scheduling Method for Band Matrices', fontsize=14)
plt.grid(True, which="both", linestyle='--', linewidth=0.5)
plt.legend(fontsize=10)
plt.tight_layout()

# Отображение графика
plt.show()

# %%
# задание 6
import matplotlib.pyplot as plt

# Данные
iterations = [1000, 10000, 100000, 1000000]
time_static = [0.005172, 0.035358, 0.160563, 1.373640]
time_dynamic = [0.003710, 0.018810, 0.135275, 1.304720]
time_guided = [0.003317, 0.015925, 0.128657, 1.302850]

# Построение графика
plt.figure(figsize=(10, 6))
plt.plot(iterations, time_static, label="Static", marker='o')
plt.plot(iterations, time_dynamic, label="Dynamic", marker='o')
plt.plot(iterations, time_guided, label="Guided", marker='o')

plt.xscale('log')
plt.xlabel("Number of Iterations (log scale)")
plt.ylabel("Execution Time (seconds)")
plt.title("Execution Time by Scheduling Strategy")
plt.legend()
plt.grid(True, which="both", linestyle='--', linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

array_sizes = [1000, 10000, 100000, 1000000, 10000000]

time_atomic = [0.000730038, 0.000399113, 0.00275588, 0.0402598, 0.321489]
time_critical = [0.017483, 0.00184417, 0.0954812, 1.64216, 25.592]
time_lock = [0.000539064, 0.022754, 0.262047, 1.95365, 27.36]
time_openmp_reduction = [0.000104904, 0.000146866, 0.000167131, 0.000632048, 0.00559497]

plt.figure(figsize=(10, 6))

plt.plot(array_sizes, time_atomic, label='Atomic', marker='o', linestyle='-', color='b')
plt.plot(array_sizes, time_critical, label='Critical', marker='o', linestyle='-', color='r')
plt.plot(array_sizes, time_lock, label='Lock', marker='o', linestyle='-', color='g')
plt.plot(array_sizes, time_openmp_reduction, label='OpenMP Reduction', marker='o', linestyle='-', color='purple')

plt.yscale('log')

plt.xlabel('Array Size')
plt.ylabel('Execution Time (seconds)')
plt.title('Comparison of Reduction Methods by Execution Time')
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

vector_sizes = [100, 1000, 10000, 100000, 1000000, 10000000]
read_times = [0.000397921, 0.00110888, 0.010941, 0.0437651, 0.328884, 3.37495]
compute_times = [0.000575066, 0.000292063, 0.000618935, 0.000260115, 0.000944138, 0.00990796]

plt.figure(figsize=(10, 6))
plt.plot(vector_sizes, read_times, marker='o', label='Time for Reading Vectors', color='blue')
plt.plot(vector_sizes, compute_times, marker='o', label='Time for Computing Dot Product', color='green')

plt.title('Performance Analysis: Dot Product Calculation', fontsize=14)
plt.xlabel('Vector Size', fontsize=12)
plt.ylabel('Time (seconds)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)
plt.xscale('log')
plt.tight_layout()
plt.show()

# %%
# Задание 9
import matplotlib.pyplot as plt
sizes = ['10x10', '100x100', '1000x1000', '10000x10000', '100000x100000']
time_no_parallelism = [0.00103, 0.00041, 0.00278, 0.09898, 38.19910]
time_with_parallelism = [0.00222, 0.01162, 0.06746, 0.54560, 35.82350]

plt.figure(figsize=(10, 6))
plt.plot(sizes, time_no_parallelism, label='Without nested parallelism', marker='o')
plt.plot(sizes, time_with_parallelism, label='With nested parallelism', marker='o')
plt.xlabel('Matrix Size')
plt.ylabel('Time (seconds)')
plt.title('Execution Time with and without Nested Parallelism vs Matrix Size')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
